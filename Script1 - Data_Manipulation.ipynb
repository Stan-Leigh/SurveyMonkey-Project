# %%
import pandas as pd
import os

# %%
pwd = os.getcwd() # pwd -> present working directory

# %%
# Read the data

df = pd.read_excel(pwd + '\\Data - Survey Monkey Output Edited.xlsx', sheet_name='Edited_Data')
df.head()
# Out:
#    Respondent ID          Start Date            End Date  Email Address  \
# 0     5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1     2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2     4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3     5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4     3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
#
#    First Name  Last Name  Custom Data 1  \
# 0         NaN        NaN            NaN
# 1         NaN        NaN            NaN
# 2         NaN        NaN            NaN
# 3         NaN        NaN            NaN
# 4         NaN        NaN            NaN
#
#   Identify which division you work in. - Response  \
# 0                                  Infrastructure
# 1                                         Finance
# 2                                  Infrastructure
# 3                                  Infrastructure
# ...

# %%
# Dimension of the data

df.shape
# Out:
# (198, 100)

# %%
df_modified = df.copy() # Create a copy to be able to rollback changes

# %%
df_modified.columns
# Out:
# Index(['Respondent ID', 'Start Date', 'End Date', 'Email Address',
#        'First Name', 'Last Name', 'Custom Data 1',
#        'Identify which division you work in. - Response',
#        'Identify which division you work in. - Other (please specify)',
#        'Which of the following best describes your position level? - Response',
#        'Which generation are you apart of? - Response',
#        'Please select the gender in which you identify. - Response',
#        'Which duration range best aligns with your tenure at your company? - Response',
#        'Which of the following best describes your employment type? - Response',
#        'Question 1 - Response', 'Question 2 - Response',
#        'Question 3 - Open-Ended Response', 'Question 4 - Response',
#        'Question 4 - Other (please specify)', 'Question 5 - Response 1',
#        'Question 5 - Response 2', 'Question 5 - Response 3',
#        'Question 5 - Response 4', 'Question 5 - Response 5',
# ...

# %%
columns_to_drop = ['Start Date', 'End Date', 'Email Address', 'First Name', 'Last Name', 'Custom Data 1']

df_modified.drop(columns=columns_to_drop, inplace=True)

df_modified.head()
# Out:
#    Respondent ID Identify which division you work in. - Response  \
# 0     5379192392                                  Infrastructure
# 1     2658722536                                         Finance
# 2     4044163394                                  Infrastructure
# 3     5535865599                                  Infrastructure
# 4     3356802928                                 Port Operations
#
#   Identify which division you work in. - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of the following best describes your position level? - Response  \
# 0                                              Staff
# 1                                              Staff
# 2                                    Department Lead
# ...

# %%
# Melt the data into the required format

id_vars = list(df_modified.columns)[:8]
value_vars = list(df_modified.columns)[8:]

df_melted = df_modified.melt(id_vars=id_vars, value_vars=value_vars, var_name='Question + SubQuestion', value_name='Answer')
df_melted.head(10)
# Out:
#    Respondent ID Identify which division you work in. - Response  \
# 0     5379192392                                  Infrastructure
# 1     2658722536                                         Finance
# 2     4044163394                                  Infrastructure
# 3     5535865599                                  Infrastructure
# 4     3356802928                                 Port Operations
# 5     3399511781                                  Infrastructure
# 6     9860597462                                  Infrastructure
# 7     1494621946                                  Infrastructure
# 8     8646387163                          Information Technology
# 9     2455127238                          Information Technology
#
#   Identify which division you work in. - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
df1 = pd.read_excel(pwd + '\\Data - Survey Monkey Output Edited.xlsx', sheet_name='Question')
df1.head()
# Out:
#     Raw Question Raw Subquestion       Question Subquestion  \
# 0  Respondent ID             NaN  Respondent ID         NaN
# 1     Start Date             NaN     Start Date         NaN
# 2       End Date             NaN       End Date         NaN
# 3  Email Address             NaN  Email Address         NaN
# 4     First Name             NaN     First Name         NaN
#
#   Question + Subquestion
# 0          Respondent ID
# 1             Start Date
# 2               End Date
# 3          Email Address
# 4             First Name

# %%
df1_modified = df1.copy()
df1_modified.drop(columns=['Raw Question', 'Subquestion', 'Raw Subquestion'], inplace=True)

# %%
df1_modified.head(9)
# Out:
#                                Question  \
# 0                         Respondent ID
# 1                            Start Date
# 2                              End Date
# 3                         Email Address
# 4                            First Name
# 5                             Last Name
# 6                         Custom Data 1
# 7  Identify which division you work in.
# 8  Identify which division you work in.
#
#                               Question + Subquestion
# 0                                      Respondent ID
# 1                                         Start Date
# 2                                           End Date
# 3                                      Email Address
# 4                                         First Name
# 5                                          Last Name
# 6                                      Custom Data 1
# 7    Identify which division you work in. - Response
# 8  Identify which division you work in. - Other (...

# %%
# Merge the two dataframes to find the original question for every question_and_subquestion

df_merged = df_melted.merge(df1_modified, how='left', left_on='Question + SubQuestion', right_on='Question + Subquestion')

# Check if the merge happened correctly
print(f'Original data: {len(df_melted)} rows')
print(f'Merged data: {len(df_merged)} rows')

df_merged.head()
# Out:
# Original data: 17028 rows
# Merged data: 17028 rows
#    Respondent ID Identify which division you work in. - Response  \
# 0     5379192392                                  Infrastructure
# 1     2658722536                                         Finance
# 2     4044163394                                  Infrastructure
# 3     5535865599                                  Infrastructure
# 4     3356802928                                 Port Operations
#
#   Identify which division you work in. - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of the following best describes your position level? - Response  \
# 0                                              Staff
# 1                                              Staff
# ...

# %%
# How many people answered each question?

respondents = df_merged[df_merged['Answer'].notna()]
respondents = respondents.groupby('Question')['Respondent ID'].nunique().reset_index()
respondents.rename(columns={'Respondent ID': 'Respondents'}, inplace=True)
respondents
# Out:
#        Question  Respondents
# 0    Question 1          119
# 1   Question 10          198
# 2   Question 11          164
# 3   Question 12          114
# 4   Question 13          108
# 5   Question 14          105
# 6   Question 15          114
# 7   Question 16          117
# 8   Question 17          135
# 9   Question 18          109
# 10  Question 19          157
# 11   Question 2          118
# 12  Question 20          105
# 13  Question 21          127
# 14  Question 22          160
# 15  Question 23          120
# 16  Question 24          195
# 17  Question 25          198
# 18  Question 26          193
# 19  Question 27          153
# 20  Question 28          119
# 21  Question 29          198
# 22   Question 3          117
# 23  Question 30          182
# 24   Question 4          161
# 25   Question 5          194
# 26   Question 6          196
# 27   Question 7          162
# 28   Question 8          190
# 29   Question 9          188

# %%
# Merge the two dataframes to find the number of respondents that answered each question

df_merged_two = df_merged.merge(respondents, how='left', left_on='Question', right_on='Question')

# Check if the merge happened correctly
print(f'Original data: {len(df_merged)} rows')
print(f'Merged data: {len(df_merged_two)} rows')

df_merged_two.head()
# Out:
# Original data: 17028 rows
# Merged data: 17028 rows
#    Respondent ID Identify which division you work in. - Response  \
# 0     5379192392                                  Infrastructure
# 1     2658722536                                         Finance
# 2     4044163394                                  Infrastructure
# 3     5535865599                                  Infrastructure
# 4     3356802928                                 Port Operations
#
#   Identify which division you work in. - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of the following best describes your position level? - Response  \
# 0                                              Staff
# 1                                              Staff
# ...

# %%
# How many people gave the same answer for each question?

same_answer = df_merged.copy() # [df_merged['Answer'].notna()]
same_answer = same_answer.groupby(['Question + Subquestion', 'Answer'])['Respondent ID'].nunique().reset_index()
same_answer.rename(columns={'Respondent ID': 'Same Answer'}, inplace=True)
same_answer
# Out:
#       Question + Subquestion    Answer  Same Answer
# 0      Question 1 - Response  Answer 1           14
# 1      Question 1 - Response  Answer 2           10
# 2      Question 1 - Response  Answer 3           13
# 3      Question 1 - Response  Answer 4           17
# 4      Question 1 - Response  Answer 5           22
# ..                       ...       ...          ...
# 683  Question 9 - Response 4  Answer 4           16
# 684  Question 9 - Response 4  Answer 5           13
# 685  Question 9 - Response 4  Answer 6           14
# 686  Question 9 - Response 4  Answer 7           12
# 687  Question 9 - Response 4  Answer 8           19
#
# [688 rows x 3 columns]

# %%
df_merged_three = df_merged_two.merge(same_answer, how='left', left_on=['Question + Subquestion', 'Answer'], right_on=['Question + Subquestion', 'Answer'])
df_merged_three['Same Answer'].fillna(0, inplace=True)

# Check if the merge happened correctly
print(f'Original data: {len(df_merged_two)} rows')
print(f'Merged data: {len(df_merged_three)} rows')

df_merged_three.head()
# Out:
# Original data: 17028 rows
# Merged data: 17028 rows
#    Respondent ID Identify which division you work in. - Response  \
# 0     5379192392                                  Infrastructure
# 1     2658722536                                         Finance
# 2     4044163394                                  Infrastructure
# 3     5535865599                                  Infrastructure
# 4     3356802928                                 Port Operations
#
#   Identify which division you work in. - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which of the following best describes your position level? - Response  \
# 0                                              Staff
# 1                                              Staff
# ...

# %%
output = df_merged_three.copy()
output.rename(columns={'Identify which division you work in. - Response': 'Division Primary',
                        'Identify which division you work in. - Other (please specify)': 'Division Secondary',
                        'Which of the following best describes your position level? - Response': 'Position',
                        'Which generation are you apart of? - Response': 'Generation',
                        'Please select the gender in which you identify. - Response': 'Gender',
                        'Which duration range best aligns with your tenure at your company? - Response': 'Tenure',
                        'Which of the following best describes your employment type? - Response': 'Employment type'}, 
                        inplace=True)
output.head()
# Out:
#    Respondent ID Division Primary Division Secondary         Position  \
# 0     5379192392   Infrastructure                NaN            Staff
# 1     2658722536          Finance                NaN            Staff
# 2     4044163394   Infrastructure                NaN  Department Lead
# 3     5535865599   Infrastructure                NaN          Manager
# 4     3356802928  Port Operations                NaN          Manager
#
#                               Generation      Gender      Tenure  \
# 0  Generation X (born between 1965-1980)        Male   0-2 years
# 1                                    NaN         NaN   10+ years
# 2  Generation X (born between 1965-1980)        Male   3-5 years
# 3    Millennial (born between 1981-2000)  Non-Binary  5-10 years
# 4  Generation X (born between 1965-1980)      Female   10+ years
#
#       Employment type Question + SubQuestion    Answer    Question  \
# 0  Full time Employee  Question 1 - Response       NaN  Question 1
# ...

# %%
output.to_excel(pwd + '\\Final_Output.xlsx', index=False)
